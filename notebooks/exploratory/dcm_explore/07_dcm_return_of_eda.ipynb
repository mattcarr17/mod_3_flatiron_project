# %% [markdown]
# # picking up from my question in notebook 06- I want to see if I can discover anything about the Waterpoint Type "Other"

# %% [markdown]
# ### Our metric is

# %%
# Standard imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#additional EDA
from pandas_profiling import ProfileReport

# Model selection
from sklearn.model_selection import train_test_split, KFold, cross_val_score, GridSearchCV

# Preprocessing
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# Models
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

# Metrics
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix, plot_confusion_matrix, classification_report

# Ensemble/XGBoost
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier

# Visualizing
from sklearn.tree import export_graphviz
from IPython.display import Image  
from sklearn.tree import export_graphviz
from pydotplus import graph_from_dot_data
from sklearn.tree import plot_tree

# %% [markdown]
# ### Reading in the geodata_clean csv... Amanda's research showed that some observations needed to be dropped. see README for details.

# %%
df = pd.read_csv("../geodata_clean.csv")
df.head()
# Out:
#    Unnamed: 0     id  amount_tsh date_recorded        funder  gps_height  \
# 0           0  69572      6000.0    2011-03-14         Roman        1390
# 1           1   8776         0.0    2013-03-06       Grumeti        1399
# 2           2  34310        25.0    2013-02-25  Lottery Club         686
# 3           3  67743         0.0    2013-01-28        Unicef         263
# 4           4  19728         0.0    2011-07-13   Action In A           0
#
#       installer  longitude   latitude              wpt_name  ...  \
# 0         Roman  34.938093  -9.856322                  none  ...
# 1       GRUMETI  34.698766  -2.147466              Zahanati  ...
# 2  World vision  37.460664  -3.821329           Kwa Mahundi  ...
# 3        UNICEF  38.486161 -11.155298  Zahanati Ya Nanyumbu  ...
# 4       Artisan  31.130847  -1.825359               Shuleni  ...
#
#    quantity_group                source           source_type source_class  \
# 0          enough                spring                spring  groundwater
# 1    insufficient  rainwater harvesting  rainwater harvesting      surface
# 2          enough                   dam                   dam      surface
# 3             dry           machine dbh              borehole  groundwater
# 4        seasonal  rainwater harvesting  rainwater harvesting      surface
#
#                waterpoint_type  waterpoint_type_group    status_group  \
# 0           communal standpipe     communal standpipe      functional
# 1           communal standpipe     communal standpipe      functional
# 2  communal standpipe multiple     communal standpipe      functional
# 3  communal standpipe multiple     communal standpipe  non functional
# 4           communal standpipe     communal standpipe      functional
#
#                                  geometry          x          y
# 0  POINT (34.93809275 -9.856321769999999)  34.938093  -9.856322
# 1          POINT (34.6987661 -2.14746569)  34.698766  -2.147466
# 2         POINT (37.46066446 -3.82132853)  37.460664  -3.821329
# 3        POINT (38.48616088 -11.15529772)  38.486161 -11.155298
# 4         POINT (31.13084671 -1.82535885)  31.130847  -1.825359
#
# [5 rows x 45 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57588 entries, 0 to 57587
# Data columns (total 45 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             57588 non-null  int64
#  1   id                     57588 non-null  int64
#  2   amount_tsh             57588 non-null  float64
#  3   date_recorded          57588 non-null  object
#  4   funder                 53966 non-null  object
#  5   gps_height             57588 non-null  int64
#  6   installer              53952 non-null  object
#  7   longitude              57588 non-null  float64
#  8   latitude               57588 non-null  float64
#  9   wpt_name               57588 non-null  object
#  10  num_private            57588 non-null  int64
#  11  basin                  57588 non-null  object
#  12  subvillage             57217 non-null  object
#  13  region                 57588 non-null  object
#  14  region_code            57588 non-null  int64
#  15  district_code          57588 non-null  int64
#  16  lga                    57588 non-null  object
#  17  ward                   57588 non-null  object
#  18  population             57588 non-null  int64
#  19  public_meeting         54612 non-null  object
#  20  recorded_by            57588 non-null  object
#  21  scheme_management      53838 non-null  object
#  22  scheme_name            30896 non-null  object
#  23  permit                 54532 non-null  object
#  24  construction_year      57588 non-null  int64
#  25  extraction_type        57588 non-null  object
#  26  extraction_type_group  57588 non-null  object
#  27  extraction_type_class  57588 non-null  object
#  28  management             57588 non-null  object
#  29  management_group       57588 non-null  object
#  30  payment                57588 non-null  object
#  31  payment_type           57588 non-null  object
#  32  water_quality          57588 non-null  object
#  33  quality_group          57588 non-null  object
#  34  quantity               57588 non-null  object
#  35  quantity_group         57588 non-null  object
#  36  source                 57588 non-null  object
#  37  source_type            57588 non-null  object
#  38  source_class           57588 non-null  object
#  39  waterpoint_type        57588 non-null  object
#  40  waterpoint_type_group  57588 non-null  object
#  41  status_group           57588 non-null  object
#  42  geometry               57588 non-null  object
#  43  x                      57588 non-null  float64
#  44  y                      57588 non-null  float64
# dtypes: float64(5), int64(8), object(32)
# memory usage: 19.8+ MB

# %% [markdown]
# I want to see the count of "other" waterpoint types by status

# %%
cat_df = df[['waterpoint_type','waterpoint_type_group', 'basin',
             'extraction_type', 'extraction_type_group', 'extraction_type_class']]

# %%
cat_df.loc[:, ('waterpoint_type','waterpoint_type_group', 'basin',
             'extraction_type', 'extraction_type_group', 'extraction_type_class')].astype('category')
# Out:
#                    waterpoint_type waterpoint_type_group  \
# 0               communal standpipe    communal standpipe
# 1               communal standpipe    communal standpipe
# 2      communal standpipe multiple    communal standpipe
# 3      communal standpipe multiple    communal standpipe
# 4               communal standpipe    communal standpipe
# ...                            ...                   ...
# 57583           communal standpipe    communal standpipe
# 57584           communal standpipe    communal standpipe
# 57585                    hand pump             hand pump
# 57586                    hand pump             hand pump
# 57587                    hand pump             hand pump
#
#                          basin extraction_type extraction_type_group  \
# 0                   Lake Nyasa         gravity               gravity
# 1                Lake Victoria         gravity               gravity
# 2                      Pangani         gravity               gravity
# 3      Ruvuma / Southern Coast     submersible           submersible
# 4                Lake Victoria         gravity               gravity
# ...                        ...             ...                   ...
# 57583                  Pangani         gravity               gravity
# 57584                   Rufiji         gravity               gravity
# 57585                   Rufiji          swn 80                swn 80
# 57586                   Rufiji     nira/tanira           nira/tanira
# 57587              Wami / Ruvu     nira/tanira           nira/tanira
#
#       extraction_type_class
# 0                   gravity
# 1                   gravity
# 2                   gravity
# 3               submersible
# 4                   gravity
# ...                     ...
# 57583               gravity
# 57584               gravity
# 57585              handpump
# 57586              handpump
# 57587              handpump
#
# [57588 rows x 6 columns]

# %%
def plot_category(df, category):
    new_df = cat_df(df, category)

    fig, ax = plt.subplots(figsize=(15, 10))

    x_labels = new_df.columns
    y = new_df.values
    width = .25
    x1 = np.arange(len(y[0]))
    x2 = [x + width for x in x1]
    x3 = [x + width for x in x2]
    labels = new_df.index
    ax.bar(x1, y[0], label=labels[0], width=width)
    ax.bar(x2, y[1], label=labels[1], width=width)
    ax.bar(x3, y[2], label=labels[2], width=width)
    ax.set_title('Number of Pumps Per {} Category'.format(category.replace('_', ' ').title()), fontsize=18)
    ax.set_ylabel('Number of Pumps', fontsize=15)
    ax.set_xlabel('{} Categories'.format(category.replace('_', ' ').title()), fontsize=15)
    plt.xticks([r + width for r in range(len(y[0]))], x_labels)
    plt.legend()

    return new_df

# %%
fig, ax = plt.subplots(figsize=(15, 10))

x_labels = cat_df.waterpoint_type
y = cat_df.values

x = cat_df.waterpoint_type.values
y = cat_df.values.sum()

# Create just a figure and only one subplot
fig, ax = plt.subplots(figsize=(15, 10))
ax.plot(x, y)
ax.set_title('Simple plot')
